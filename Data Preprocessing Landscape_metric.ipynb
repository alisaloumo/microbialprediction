# %%
import pylandstats as pls
# Out:
# Module C:\Users\alisa\anaconda3\Lib\site-packages\pylandstats\landscape.py has not been compiled for Transonic-Numba

# %%
input_filepaths = [
    r'C:\Users\alisa\Downloads\Landcover\Watershed\Watershed 1\LULC2001\Reclass_Watershed1_2001.tif',
    r'C:\Users\alisa\Downloads\Landcover\Watershed\Watershed 1\LULC2004\Reclass_Watershed1_2004.tif',
    r'C:\Users\alisa\Downloads\Landcover\Watershed\Watershed 1\LULC2006\Reclass_Watershed1_2006.tif',
    r'C:\Users\alisa\Downloads\Landcover\Watershed\Watershed 1\LULC2008\Reclass_Watershed1_2008.tif',
    r'C:\Users\alisa\Downloads\Landcover\Watershed\Watershed 1\LULC2011\Reclass_Watershed1_2011.tif',
    r'C:\Users\alisa\Downloads\Landcover\Watershed\Watershed 1\LULC2013\Reclass_Watershed1_2013.tif',
    r'C:\Users\alisa\Downloads\Landcover\Watershed\Watershed 1\LULC2016\Reclass_Watershed1_2016.tif',
    r'C:\Users\alisa\Downloads\Landcover\Watershed\Watershed 1\LULC2019\Reclass_Watershed1_2019.tif',
    r'C:\Users\alisa\Downloads\Landcover\Watershed\Watershed 1\LULC2021\Reclass_Watershed1_2021.tif'
]

sta = pls.SpatioTemporalAnalysis(input_filepaths, dates=[2001, 2004, 2006, 2008, 2011, 2013, 2016,2019, 2021])

# %%
class_metrics_df = sta.compute_class_metrics_df()

# %%
sta.compute_class_metrics_df()
# Out:
# metric           total_area  proportion_of_landscape  number_of_patches  \
# class_val dates
# 1         2001        79.29                 3.616585               23.0
#           2004        77.31                 3.526273               23.0
#           2006        75.24                 3.431856               22.0
#           2008        75.33                 3.435961               23.0
#           2011        73.44                 3.349754               23.0
#           2013        74.70                 3.407225               21.0
#           2016        76.05                 3.468801               23.0
#           2019        76.05                 3.468801               23.0
#           2021        76.05                 3.468801               23.0
# 2         2001      1465.11                66.826765               90.0
#           2004      1467.54                66.937603               90.0
#           2006      1492.38                68.070608               90.0
# ...

# %%
class_metrics_df.to_excel('class_metrics_Watershed1.xlsx')

# %%
landscape_metrics_df = sta.compute_landscape_metrics_df()

# %%
sta.compute_landscape_metrics_df()
# Out:
# metric  total_area  number_of_patches  patch_density  largest_patch_index  \
# dates
# 2001        2192.4              399.0      18.199234            61.395731
# 2004        2192.4              414.0      18.883415            61.408046
# 2006        2192.4              402.0      18.336070            62.290640
# 2008        2192.4              408.0      18.609743            62.779146
# 2011        2192.4              410.0      18.700967            63.559113
# 2013        2192.4              404.0      18.427294            63.616585
# 2016        2192.4              405.0      18.472906            64.400657
# 2019        2192.4              409.0      18.655355            64.905583
# 2021        2192.4              409.0      18.655355            64.905583
#
# metric  total_edge  edge_density  landscape_shape_index  effective_mesh_size  \
# dates
# 2001      245970.0    112.192118              14.678914           846.631027
# ...

# %%
landscape_metrics_df.to_excel('landscape_metrics_Watershed1.xlsx')
